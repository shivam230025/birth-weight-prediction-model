# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('model/linerRegressionModel.pkl', 'rb') as obj:
    mymodel= pickle.load(obj)

# %%
baby_testData_dict= {
    'gestation': [290],
    'parity': [1],
    'age': [30],
    'height': [60],
    'weight': [110],
    'smoke': [1.0]
}

# %%
baby_testData_df= pd.DataFrame(baby_testData_dict)
baby_testData_df
# Out:
#    gestation  parity  age  height  weight  smoke
# 0        290       1   30      60     110    1.0

# %%
prediction= mymodel.predict(baby_testData_df)
prediction
# Out:
# array([111.27876904])

# %%
prediction= round(float(prediction[0]), 2)
prediction
# Out:
# 111.28
